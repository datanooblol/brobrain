# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from brobrain.llms.local.embedding import OllamaEmbedding

# %%
embedding = OllamaEmbedding(model="bge-m3")

# %%
texts = ["Hey", "ha"]
vectors = embedding.run(texts)

# %%
from brobrain.llms.local.llm import OllamaLlama

llm = OllamaLlama(model="mrasif/llama3.2:1b")

# %%
llm.run("Helpful assistant", [dict(role="user", content="Hello")])
# Out:
# ModelResponse(model='mrasif/llama3.2:1b', role='assistant', content="How can I assist you today? Is there something on your mind that you'd like to talk about, or are you just looking for some general information?")
